# %% [markdown]
# In this exercise you'll try to build a neural network that predicts the price of a house according to a simple formula.
#
# So, imagine if house pricing was as easy as a house costs 50k + 50k per bedroom, so that a 1 bedroom house costs 100k, a 2 bedroom house costs 150k etc.
#
# How would you create a neural network that learns this relationship so that it would predict a 7 bedroom house as costing close to 400k etc.
#
# Hint: Your network might work better if you scale the house price down. You don't have to give the answer 400...it might be better to create something that predicts the number 4, and then your answer is in the 'hundreds of thousands' etc.

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %%
# GRADED FUNCTION: house_model
def house_model(y_new):
    xs = np.array([1,2,3],dtype=float) # Your Code Here#
    ys = np.array([1,1.5,2],dtype=float)# Your Code Here# # hundreds of thousands USD
    model = keras.Sequential([keras.layers.Dense(units=1,input_shape=[1])])# Your Code Here#
    model.compile(optimizer='sgd',loss='mean_squared_error')# Your Code Here#
    model.fit(xs,ys,epochs=300)# Your Code here#
    return model.predict(y_new)[0]

# %%
prediction = house_model([7.0])
print(prediction)
# Out:
# Epoch 1/300
# 3/3 [==============================] - 0s 66ms/sample - loss: 6.7915
# Epoch 2/300
# 3/3 [==============================] - 0s 622us/sample - loss: 5.3684
# Epoch 3/300
# 3/3 [==============================] - 0s 563us/sample - loss: 4.2435
# Epoch 4/300
# 3/3 [==============================] - 0s 614us/sample - loss: 3.3544
# Epoch 5/300
# 3/3 [==============================] - 0s 566us/sample - loss: 2.6515
# Epoch 6/300
# 3/3 [==============================] - 0s 662us/sample - loss: 2.0960
# Epoch 7/300
# 3/3 [==============================] - 0s 607us/sample - loss: 1.6569
# Epoch 8/300
# 3/3 [==============================] - 0s 636us/sample - loss: 1.3097
# Epoch 9/300
# 3/3 [==============================] - 0s 565us/sample - loss: 1.0354
# Epoch 10/300
# 3/3 [==============================] - 0s 597us/sample - loss: 0.8185
# Epoch 11/300
# 3/3 [==============================] - 0s 534us/sample - loss: 0.6471
# Epoch 12/300
# ...
